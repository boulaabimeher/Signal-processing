# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np #numérique de python
import pandas as pd #dataframe

# %% [markdown]
# ## Read Data

# %%
# Create an empty DataFrame to store the combined data
combined_data = pd.DataFrame()

# Read and combine the data from all tables
for file_name, class_label in zip(file_names, class_labels):
    data = pd.read_excel(file_name, usecols=['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9'])
    data['Class'] = class_label  # Add a 'Class' column with the corresponding label
    combined_data = pd.concat([combined_data, data], ignore_index=True)

# %%
combined_data
# Out:
#             X1        X2        X3        X4          X5          X6  \
# 0     0.610106 -0.516968 -0.133428  2.495667 -144.147034  122.629852
# 1     0.616820 -0.510254 -0.153569  2.410522 -146.352997  119.893494
# 2     0.616820 -0.503540 -0.173711  2.205231 -147.003937  116.747284
# 3     0.623534 -0.490112 -0.193853  2.185364 -148.571014  113.155060
# 4     0.630248 -0.476685 -0.207280  2.365112 -150.499725  110.611572
# ...        ...       ...       ...       ...         ...         ...
# 5995  0.086425 -0.100708 -0.039434 -0.028381   93.783569 -153.007050
# 5996  0.052855 -0.093994 -0.039434 -0.010406   97.182922 -152.548981
# 5997  0.093139 -0.100708 -0.039434 -0.020813  101.522522 -151.777496
# 5998  0.052855 -0.093994 -0.046147 -0.012299  104.741058 -150.861359
# 5999  0.099853 -0.107422 -0.046147 -0.012299  108.622589 -149.776459
#
#              X7          X8         X9  Class
# 0     20.468445  147.949219  90.045166      0
# ...

# %%
# Checking the columns
combined_data.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'Class'], dtype='object')

# %%
combined_data['Class'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
combined_data.isnull().sum()
# Out:
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
# X6       0
# X7       0
# X8       0
# X9       0
# Class    0
# dtype: int64

# %%
plt.style.use('dark_background')
sns.heatmap(combined_data.isnull())
# Out:
# <Axes: >

# %%
# Checking the basic information of the Combined Data
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      6000 non-null   float64
#  1   X2      6000 non-null   float64
#  2   X3      6000 non-null   float64
#  3   X4      6000 non-null   float64
#  4   X5      6000 non-null   float64
#  5   X6      6000 non-null   float64
#  6   X7      6000 non-null   float64
#  7   X8      6000 non-null   float64
#  8   X9      6000 non-null   float64
#  9   Class   6000 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 468.9 KB

# %%
# Checking the duplicate Records
combined_data.duplicated().sum()
# Out:
# 0

# %%
# Description of data
combined_data.drop('Class', axis=1).describe().T
# Out:
#      count        mean         std         min         25%         50%  \
# X1  6000.0    0.214035    2.162893   -6.291749   -0.316407   -0.020997
# X2  6000.0   -0.026655    1.890948   -7.297974   -0.221558   -0.033569
# X3  6000.0   -0.284263    2.047898  -12.856206   -0.381841   -0.032720
# X4  6000.0    1.949019    1.011208   -0.415314    1.911011    2.282806
# X5  6000.0    0.911246  109.793242 -158.877563 -109.249420    0.608749
# X6  6000.0    0.848354  109.823184 -158.877563 -109.261475    0.608749
# X7  6000.0    0.793863  109.792532 -157.105560 -108.817469    0.912120
# X8  6000.0  126.940137   59.356087    0.000000  129.785156  144.726562
# X9  6000.0   70.327032   31.376976  -16.558838   60.604858   86.645508
#
#            75%         max
# X1    0.334838   13.769286
# X2    0.107422    6.828003
# X3    0.215693    6.211177
# X4    2.468231   11.208740
# X5  110.674858  158.841400
# X6  110.662804  159.347687
# X7  110.519155  158.419495
# X8  147.656250  220.019531
# ...

# %%
#Shape of signal
print('Size of data0:', data0.shape)
print('Size of data1:', data1.shape)
print('Size of data2:', data2.shape)
print('Size of data3:', data3.shape)
print('Size of data4:', data4.shape)
print('Size of data5:', data5.shape)
# Out:
# Size of data0: (1000, 9)
# Size of data1: (1000, 9)
# Size of data2: (1000, 9)
# Size of data3: (1000, 9)
# Size of data4: (1000, 9)
# Size of data5: (1000, 9)

# %%
y = combined_data['Class']

# %%
y.value_counts()
# Out:
# 0    1000
# 1    1000
# 2    1000
# 3    1000
# 4    1000
# 5    1000
# Name: Class, dtype: int64
